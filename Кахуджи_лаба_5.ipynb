# %% [markdown]
# <a href="https://colab.research.google.com/github/Drobilk/LAB-SEMESTR-2/blob/main/%D0%9A%D0%B0%D1%85%D1%83%D0%B4%D0%B6%D0%B8_%D0%BB%D0%B0%D0%B1%D0%B0_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files 
uploaded = files.upload()
# Out:
#      <input type="file" id="files-8efc05f9-767e-47fe-a89e-bd4d14260716" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8efc05f9-767e-47fe-a89e-bd4d14260716">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving creditcard.csv to creditcard (1).csv

# %%
import pandas as pd
df=pd.read_csv('creditcard.csv')
df.head()
# Out:
#    Time        V1        V2        V3  ...       V27       V28  Amount  Class
# 0     0 -1.359807 -0.072781  2.536347  ...  0.133558 -0.021053  149.62    0.0
# 1     0  1.191857  0.266151  0.166480  ... -0.008983  0.014724    2.69    0.0
# 2     1 -1.358354 -1.340163  1.773209  ... -0.055353 -0.059752  378.66    0.0
# 3     1 -0.966272 -0.185226  1.792993  ...  0.062723  0.061458  123.50    0.0
# 4     2 -1.158233  0.877737  1.548718  ...  0.219422  0.215153   69.99    0.0
#
# [5 rows x 31 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90805 entries, 0 to 90804
# Data columns (total 31 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Time    90805 non-null  int64
#  1   V1      90805 non-null  float64
#  2   V2      90805 non-null  float64
#  3   V3      90805 non-null  float64
#  4   V4      90805 non-null  float64
#  5   V5      90805 non-null  float64
#  6   V6      90805 non-null  float64
#  7   V7      90805 non-null  float64
#  8   V8      90805 non-null  float64
#  9   V9      90805 non-null  float64
#  10  V10     90805 non-null  float64
#  11  V11     90805 non-null  float64
#  12  V12     90805 non-null  float64
#  13  V13     90805 non-null  float64
#  14  V14     90805 non-null  float64
#  15  V15     90805 non-null  float64
#  16  V16     90805 non-null  float64
#  17  V17     90805 non-null  float64
#  18  V18     90805 non-null  float64
#  19  V19     90804 non-null  float64
# ...

# %%
df.drop(['Time', 'Amount', 'Class'], axis=1, inplace=True)

# %%
df.head()
# Out:
#          V4        V5        V6  ...       V26       V27       V28
# 0  1.378155 -0.338321  0.462388  ... -0.189115  0.133558 -0.021053
# 1  0.448154  0.060018 -0.082361  ...  0.125895 -0.008983  0.014724
# 2  0.379780 -0.503198  1.800499  ... -0.139097 -0.055353 -0.059752
# 3 -0.863291 -0.010309  1.247203  ... -0.221929  0.062723  0.061458
# 4  0.403034 -0.407193  0.095921  ...  0.502292  0.219422  0.215153
#
# [5 rows x 25 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90805 entries, 0 to 90804
# Data columns (total 25 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   V4      90805 non-null  float64
#  1   V5      90805 non-null  float64
#  2   V6      90805 non-null  float64
#  3   V7      90805 non-null  float64
#  4   V8      90805 non-null  float64
#  5   V9      90805 non-null  float64
#  6   V10     90805 non-null  float64
#  7   V11     90805 non-null  float64
#  8   V12     90805 non-null  float64
#  9   V13     90805 non-null  float64
#  10  V14     90805 non-null  float64
#  11  V15     90805 non-null  float64
#  12  V16     90805 non-null  float64
#  13  V17     90805 non-null  float64
#  14  V18     90805 non-null  float64
#  15  V19     90804 non-null  float64
#  16  V20     90804 non-null  float64
#  17  V21     90804 non-null  float64
#  18  V22     90804 non-null  float64
#  19  V23     90804 non-null  float64
# ...

# %%
sns.boxplot(x='V28',data=df)

# %%
df1 = df.groupby('V12')['V7'].mean()

# %%
sns.violinplot(x = df1)

# %%
plt.figure(figsize=(20, 2))

ax = sns.countplot(x=df[:7]['V8'])

# %%
sns.heatmap(df.corr(),annot=True,cmap='Greens_r')

# %%
sns.regplot(x='V10', y='V17', data=df)

# %%
sns.pairplot(data=df)

# %%
sns.jointplot(x='V7', y='V8', data=df[:50])
