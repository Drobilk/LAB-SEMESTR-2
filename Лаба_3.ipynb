# %% [markdown]
# <a href="https://colab.research.google.com/github/Drobilk/LAB-SEMESTR-2/blob/main/%D0%9B%D0%B0%D0%B1%D0%B0_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Вариант 5

# %%
from scipy import *
from scipy.integrate import *
import math
import numpy as np
from numpy.lib.scimath import *
from scipy.integrate import simps
import sympy as sy

# %% [markdown]
# Задание 1.

# %%
from google.colab import files
from io import BytesIO
from PIL import Image

uploaded = files.upload()
im = Image.open(BytesIO(uploaded['IMG_6211.jpg']))
import matplotlib.pyplot as plt

plt.imshow(im)
plt.show()

# %% [markdown]
# Ошибка: дописала константу хотя интеграл определенный, но в программе все верно

# %%
from scipy import integrate
from math import cos, pi
 
func = lambda x: 1/cos(x)
 
answer = integrate.quad(func, 0, pi/4)
print(answer)
# Out:
# (0.881373587019543, 9.785212496055606e-15)

# %%
result = math.log((2+sqrt(2))/(2-sqrt(2)))
print(result)
# Out:
# 1.762747174039086

# %% [markdown]
# Задание 2.

# %%
from google.colab import files
from io import BytesIO
from PIL import Image

uploaded = files.upload()
im = Image.open(BytesIO(uploaded['IMG_6210.jpg']))
import matplotlib.pyplot as plt

plt.imshow(im)
plt.show()
# Out:
#      <input type="file" id="files-2bf42958-c359-49a8-84d4-e822dec59745" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2bf42958-c359-49a8-84d4-e822dec59745">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving IMG_6210.jpg to IMG_6210 (1).jpg

# %%
res = abs(math.log(10) - math.log(10)) + 1
a = 1/2
res = a*res
print(f'{res:.8f}')
# Out:
# 0.50000000

# %%
import numpy as np
from scipy.integrate import odeint
import matplotlib.pyplot as plt
def F(s, t, b, c):
    dudt = s[1]
    dvdt = -b*(s[1]*s[1]) - c*s[0]
    return [dudt, dvdt]

b = 2
c = 0

t = np.linspace(-2, 10, 1000)
sol = odeint(F, y0, t, args=(b, c))
plt.plot(t, sol[:, 0], 'r')
plt.xlabel('t')
plt.ylabel('u(t)')
plt.grid()
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# ответы на вопросы
# 1. Функция quad возвращает два значения, в которых первое число является значением интеграла, а второе значение является оценкой абсолютной ошибки в значении интеграла.
# 2. scipy.integrate — численное интегрирование (методы трапеции, Симпсона, Ромберга и др.), решение обыкновенных диффе-
# ренциальных уравнений (ОДУ)
# 3. Модуль scipy.integrate имеет две функции, одна из них odeint(), предназначенна для решения систем обыкновенных дифференциальных уравнений (ОДУ) первого порядка с начальными условиями в одной точке (задача Коши)

# %%
# 4. 
from scipy import integrate
help(integrate.quad)
# Out:
# Help on function quad in module scipy.integrate.quadpack:
#
# quad(func, a, b, args=(), full_output=0, epsabs=1.49e-08, epsrel=1.49e-08, limit=50, points=None, weight=None, wvar=None, wopts=None, maxp1=50, limlst=50)
#     Compute a definite integral.
#
#     Integrate func from `a` to `b` (possibly infinite interval) using a
#     technique from the Fortran library QUADPACK.
#
#     Parameters
#     ----------
#     func : {function, scipy.LowLevelCallable}
#         A Python function or method to integrate.  If `func` takes many
#         arguments, it is integrated along the axis corresponding to the
#         first argument.
#
#         If the user desires improved integration performance, then `f` may
#         be a `scipy.LowLevelCallable` with one of the signatures::
#
#             double func(double x)
#             double func(double x, void *user_data)
#             double func(int n, double *xx)
#             double func(int n, double *xx, void *user_data)
#
# ...

# %% [markdown]
# 5. Функция interp1d() принимает в качестве первых двух аргументов одномерные массивы координат g и соответствующих значений некоторой величины f. Функция возвращает класс, реализующий функцию, интерполирующую исходные данные заданным методом. Третий тип переменных представляет тип метода интерполяции. В нашем случае это "Кубический".
